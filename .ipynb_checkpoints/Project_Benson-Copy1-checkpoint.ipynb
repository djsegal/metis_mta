# %% [markdown]
# # Subjective
# WomenTechWomenYes (WTWY) has an annual gala at the beginning of the summer each year. As we are new and inclusive organization, we try to do double duty with the gala both to fill our event space with individuals passionate about increasing the participation of women in technology, and to concurrently build awareness and reach.

# %%
#setup import libs
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# this statement allows the visuals to render within your Jupyter Notebook, instead of a pop window
# %matplotlib inline 

# various options in pandas
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)
pd.set_option('display.precision', 3)

# %%
def import_file(File_Path, Local=False):
    """
    import file into DataFrame and strip leading and tailing 
    whitespaces if any.
    File_path: internet link(URL) or where file is stored
    Local: is it URL or File stored in local?, Defualt True(store in local)
    """
    import pandas as pd
    
    if Local:
        fh = open(File_Path)
    else:
        
        from urllib.request import urlopen  # the lib that handles the url stuff
        fh = urlopen(File_Path) # it's a file like object and works just like a file
        
    data = pd.read_csv(fh, header = 0) #import file as DataFrame
    
    fh.close()
        
    return data

# %%
#import_file('http://web.mta.info/developers/data/nyct/turnstile/turnstile_190921.txt', False)
DF_19021 = import_file('http://web.mta.info/developers/data/nyct/turnstile/turnstile_190921.txt')
DF_19021.head(5)
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  09/14/2019  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  09/14/2019  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  09/14/2019  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  09/14/2019  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  09/14/2019  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  7198818
# 1  REGULAR  7198834
# 2  REGULAR  7198847
# 3  REGULAR  7198929
# 4  REGULAR  7199125
#
#    EXITS
# 0                                            2438323
# 1                                            2438325
# 2                                            2438354
# 3                                            2438428
# 4                                            2438483

# %%
DF_19021.columns
# Out:
# Index(['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME', 'DIVISION', 'DATE', 'TIME',
#        'DESC', 'ENTRIES',
#        'EXITS                                                               '],
#       dtype='object')

# %%
# Remove whitesapce for the columns name 
DF_19021.rename(columns=lambda x: x.strip(), inplace=True)

DF_19021.sort_values(["STATION","SCP","DATE","TIME"], inplace=True)
#df = DF_19021.groupby(["STATION", "SCP"])

#Calculate ENTRIES and EXITS DIfference to get passenger number entering/exiting turnstile
DF_19021['ENTRIES_DIFF'] = DF_19021.groupby(["STATION", "SCP"])['ENTRIES'].diff()
DF_19021['EXITS_DIFF'] = DF_19021.groupby(["STATION", "SCP"])['EXITS'].diff()


# DF_19021['ENTRIES_DIFF'] = df['ENTRIES'].diff()
# DF_19021['EXITS_DIFF'] = df['EXITS'].diff()
# df['EXITS_DIFF'] = df['EXITS'].diff()

# %%
(DF_19021.groupby()
         .diff()
        .sort_values()
     .rest_index())

# %%
DF_19021.head(10)
# Out:
#         C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 31610  H007  R248  00-00-00    1 AV        L      BMT  09/14/2019  00:00:00
# 31611  H007  R248  00-00-00    1 AV        L      BMT  09/14/2019  04:00:00
# 31612  H007  R248  00-00-00    1 AV        L      BMT  09/14/2019  08:00:00
# 31613  H007  R248  00-00-00    1 AV        L      BMT  09/14/2019  12:00:00
# 31614  H007  R248  00-00-00    1 AV        L      BMT  09/14/2019  16:00:00
# 31615  H007  R248  00-00-00    1 AV        L      BMT  09/14/2019  20:00:00
# 31616  H007  R248  00-00-00    1 AV        L      BMT  09/15/2019  00:00:00
# 31617  H007  R248  00-00-00    1 AV        L      BMT  09/15/2019  04:00:00
# 31618  H007  R248  00-00-00    1 AV        L      BMT  09/15/2019  08:00:00
# 31619  H007  R248  00-00-00    1 AV        L      BMT  09/15/2019  12:00:00
#
#           DESC   ENTRIES     EXITS  ENTRIES_DIFF  EXITS_DIFF
# 31610  REGULAR  14976068  16737583           NaN         NaN
# 31611  REGULAR  14976068  16737595           0.0        12.0
# 31612  REGULAR  14976068  16737610           0.0        15.0
# 31613  REGULAR  14976068  16737636           0.0        26.0
# 31614  REGULAR  14976068  16737653           0.0        17.0
# 31615  REGULAR  14976068  16737665           0.0        12.0
# 31616  REGULAR  14976068  16737677           0.0        12.0
# 31617  REGULAR  14976068  16737682           0.0         5.0
# 31618  REGULAR  14976068  16737703           0.0        21.0
# 31619  REGULAR  14976068  16737713           0.0        10.0

# %%
DF_19021.describe()
# Out:
#          ENTRIES      EXITS  ENTRIES_DIFF  EXITS_DIFF
# count  2.049e+05  2.049e+05     2.006e+05   2.006e+05
# mean   4.211e+07  3.487e+07     2.138e+03  -2.000e+04
# std    2.156e+08  1.995e+08     1.668e+08   1.620e+08
# min    0.000e+00  0.000e+00    -2.023e+09  -2.062e+09
# 25%    2.898e+05  1.294e+05     1.000e+00   1.000e+00
# 50%    2.041e+06  1.179e+06     6.600e+01   4.800e+01
# 75%    6.619e+06  4.536e+06     3.170e+02   2.280e+02
# max    2.129e+09  2.124e+09     2.023e+09   2.062e+09

# %%
x =DF_19021.count()
y = DF_19021[(DF_19021.EXITS_DIFF < 0) | (DF_19021.ENTRIES_DIFF < 0)].count()
x / y
# Out:
# C/A             7.724
# UNIT            7.724
# SCP             7.724
# STATION         7.724
# LINENAME        7.724
# DIVISION        7.724
# DATE            7.724
# TIME            7.724
# DESC            7.724
# ENTRIES         7.724
# EXITS           7.724
# ENTRIES_DIFF    7.561
# EXITS_DIFF      7.561
# dtype: float64

# %%
#Clean data, remove negative number and numbers larger than 40000
DF_cleaned = DF_19021[(DF_19021.EXITS_DIFF >= 0) & (DF_19021.ENTRIES_DIFF >= 0)]
DF_cleaned = DF_cleaned[(DF_cleaned.EXITS_DIFF <= 4e4) & (DF_cleaned.ENTRIES_DIFF <= 4e4)]

# %%
DF_cleaned[DF_cleaned.STATION=='14 ST-UNION SQ'].SCP.count()
# Out:
# 1685

# %%
# Create new Colum for (Entries_DIFF + EXITS_DIFF)
DF_cleaned['Total_flows'] = DF_cleaned.ENTRIES_DIFF+ DF_cleaned.EXITS_DIFF
DF_cleaned.head(5)
# Out:
#         C/A  UNIT       SCP STATION LINENAME DIVISION       DATE      TIME  \
# 31611  H007  R248  00-00-00    1 AV        L      BMT 2019-09-14  04:00:00
# 31612  H007  R248  00-00-00    1 AV        L      BMT 2019-09-14  08:00:00
# 31613  H007  R248  00-00-00    1 AV        L      BMT 2019-09-14  12:00:00
# 31614  H007  R248  00-00-00    1 AV        L      BMT 2019-09-14  16:00:00
# 31615  H007  R248  00-00-00    1 AV        L      BMT 2019-09-14  20:00:00
#
#           DESC   ENTRIES     EXITS  ENTRIES_DIFF  EXITS_DIFF  Total_flows  \
# 31611  REGULAR  14976068  16737595           0.0        12.0         12.0
# 31612  REGULAR  14976068  16737610           0.0        15.0         15.0
# 31613  REGULAR  14976068  16737636           0.0        26.0         26.0
# 31614  REGULAR  14976068  16737653           0.0        17.0         17.0
# 31615  REGULAR  14976068  16737665           0.0        12.0         12.0
#
#       day_of_week Weekday
# 31611    Saturday   False
# 31612    Saturday   False
# 31613    Saturday   False
# 31614    Saturday   False
# 31615    Saturday   False

# %%
DF_19021.count()
# Out:
# C/A             204928
# UNIT            204928
# SCP             204928
# STATION         204928
# LINENAME        204928
# DIVISION        204928
# DATE            204928
# TIME            204928
# DESC            204928
# ENTRIES         204928
# EXITS           204928
# ENTRIES_DIFF    200608
# EXITS_DIFF      200608
# dtype: int64

# %%
DF_cleaned.count()
# Out:
# C/A             157532
# UNIT            157532
# SCP             157532
# STATION         157532
# LINENAME        157532
# DIVISION        157532
# DATE            157532
# TIME            157532
# DESC            157532
# ENTRIES         157532
# EXITS           157532
# ENTRIES_DIFF    157532
# EXITS_DIFF      157532
# dtype: int64

# %%
#DF_cleaned[DF_cleaned.STATION == '1 AV'].groupby(['STATION','DATE','TIME']).sum()

# %%
# Convert Date to day of week 
DF_cleaned['DATE'] = pd.to_datetime(DF_cleaned['DATE'])
DF_cleaned['day_of_week'] = DF_cleaned['DATE'].dt.day_name()

DF_cleaned.head(5)
# Out:
#         C/A  UNIT       SCP STATION LINENAME DIVISION       DATE      TIME  \
# 31611  H007  R248  00-00-00    1 AV        L      BMT 2019-09-14  04:00:00
# 31612  H007  R248  00-00-00    1 AV        L      BMT 2019-09-14  08:00:00
# 31613  H007  R248  00-00-00    1 AV        L      BMT 2019-09-14  12:00:00
# 31614  H007  R248  00-00-00    1 AV        L      BMT 2019-09-14  16:00:00
# 31615  H007  R248  00-00-00    1 AV        L      BMT 2019-09-14  20:00:00
#
#           DESC   ENTRIES     EXITS  ENTRIES_DIFF  EXITS_DIFF  Total_flows  \
# 31611  REGULAR  14976068  16737595           0.0        12.0         12.0
# 31612  REGULAR  14976068  16737610           0.0        15.0         15.0
# 31613  REGULAR  14976068  16737636           0.0        26.0         26.0
# 31614  REGULAR  14976068  16737653           0.0        17.0         17.0
# 31615  REGULAR  14976068  16737665           0.0        12.0         12.0
#
#       day_of_week
# 31611    Saturday
# 31612    Saturday
# 31613    Saturday
# 31614    Saturday
# 31615    Saturday

# %%
# Seperate weekdays and weekend DF
def IsWeekday(string):
    weekday = ['Monday','Tuesday','Wednesday','Thursday','Friday']
    if string in weekday:
        return "True"
    else:
        return "False"

DF_cleaned['Weekday'] = DF_cleaned.day_of_week.apply(lambda x: IsWeekday(x))

DF_weekdays = DF_cleaned[DF_cleaned.Weekday == "True"]
DF_weekend = DF_cleaned[DF_cleaned.Weekday == "False"]

# %%
#DF_weekdays.head(50)

#TOP_25_DF_weekend.groupby(['STATION']).ENTRIES_DIFF

# %%
# narrow down to top 25
TOP_25_DF_weekend = DF_weekend.groupby(['STATION']).sum().sort_values('Total_flows', ascending=False).reset_index().iloc[0:26]
TOP_25_DF_weekedays = DF_weekdays.groupby(['STATION']).sum().sort_values('Total_flows', ascending=False).reset_index().iloc[0:26]

#TOP_25_DF_weekend.groupby(['STATION']).ENTRIES_DIFF

# %%
TOP_25_DF_weekend['Flow_Ratio'] = TOP_25_DF_weekend.ENTRIES_DIFF/TOP_25_DF_weekend.EXITS_DIFF
TOP_25_DF_weekend['Daily_Avg'] = TOP_25_DF_weekend.Total_flows/2
TOP_25_DF_weekend.head(10)
# Out:
#            STATION      ENTRIES        EXITS  ENTRIES_DIFF  EXITS_DIFF  \
# 0   14 ST-UNION SQ   2990051503   2059774383      122316.0    123118.0
# 1  FT HAMILTON PKY     25951938     26817201       79011.0     69442.0
# 2   59 ST COLUMBUS  35903393481  31742716433       74877.0     68686.0
# 3   TIMES SQ-42 ST  23590953604  29082907076       70626.0     71461.0
# 4    FLUSHING-MAIN   2411660392   2299340652       71895.0     65103.0
# 5        FULTON ST  37150170151  44760444626       75539.0     51099.0
# 6   W 4 ST-WASH SQ   2756228291   1325611965       62165.0     60716.0
# 7   34 ST-PENN STA  36994802868  29072844595       49617.0     62494.0
# 8  JKSN HT-ROOSVLT   1802669054   1341671263       60337.0     45708.0
# 9   ATL AV-BARCLAY  10169148136   2988080073       47947.0     49421.0
#
#    Total_flows  Flow_Ratio  Daily_Avg
# 0     245434.0       0.993   122717.0
# 1     148453.0       1.138    74226.5
# 2     143563.0       1.090    71781.5
# 3     142087.0       0.988    71043.5
# 4     136998.0       1.104    68499.0
# 5     126638.0       1.478    63319.0
# 6     122881.0       1.024    61440.5
# 7     112111.0       0.794    56055.5
# 8     106045.0       1.320    53022.5
# 9      97368.0       0.970    48684.0

# %%
#TOP_25_DF_weekedays

TOP_25_DF_weekedays['Flow_Ratio'] = TOP_25_DF_weekedays.ENTRIES_DIFF/TOP_25_DF_weekedays.EXITS_DIFF
TOP_25_DF_weekedays['Daily_Avg'] = TOP_25_DF_weekedays.Total_flows/5
TOP_25_DF_weekedays.head(10)
# Out:
#            STATION       ENTRIES         EXITS  ENTRIES_DIFF  EXITS_DIFF  \
# 0   14 ST-UNION SQ    8202856605    5635439711      532145.0    498921.0
# 1        FULTON ST  103680683616  121947275774      478179.0    346497.0
# 2   59 ST COLUMBUS  101701977101   89659658375      397349.0    334138.0
# 3   TIMES SQ-42 ST   64316387537   79285973634      360708.0    328379.0
# 4   34 ST-PENN STA  100899993492   79294565047      342655.0    329665.0
# 5   47-50 STS ROCK   69991619639   69941422002      314491.0    330017.0
# 6     PATH NEW WTC     120696932     108686543      316754.0    290342.0
# 7    FLUSHING-MAIN    6269776859    5950664471      309018.0    263464.0
# 8      CHAMBERS ST   89339414723   68123660444      310051.0    238713.0
# 9  42 ST-BRYANT PK   58458108862   42515578823      233637.0    229914.0
#
#    Total_flows  Flow_Ratio  Daily_Avg
# 0    1.031e+06       1.067   206213.2
# 1    8.247e+05       1.380   164935.2
# 2    7.315e+05       1.189   146297.4
# 3    6.891e+05       1.098   137817.4
# 4    6.723e+05       1.039   134464.0
# 5    6.445e+05       0.953   128901.6
# 6    6.071e+05       1.091   121419.2
# 7    5.725e+05       1.173   114496.4
# 8    5.488e+05       1.299   109752.8
# 9    4.636e+05       1.016    92710.2

# %%
# plot
plt.barh(TOP_25_DF_weekedays.STATION,TOP_25_DF_weekedays.Daily_Avg ); #horizontal bar chart

# %%
list(DF_cleaned.groupby(['STATION']).sum().sort_values('ENTRIES_DIFF', ascending=False).index)
# Out:
# ['14 ST-UNION SQ',
#  'FULTON ST',
#  '59 ST COLUMBUS',
#  'TIMES SQ-42 ST',
#  '34 ST-PENN STA',
#  'FLUSHING-MAIN',
#  '47-50 STS ROCK',
#  'CHAMBERS ST',
#  'GRD CNTRL-42 ST',
#  'PATH NEW WTC',
#  'JKSN HT-ROOSVLT',
#  '34 ST-HERALD SQ',
#  'W 4 ST-WASH SQ',
#  'ATL AV-BARCLAY',
#  '42 ST-PORT AUTH',
#  '42 ST-BRYANT PK',
#  'FT HAMILTON PKY',
#  '14 ST',
#  'JAY ST-METROTEC',
#  '72 ST',
#  'BOROUGH HALL',
#  '86 ST',
#  'JAMAICA CENTER',
#  '57 ST-7 AV',
#  '72 ST-2 AVE',
#  'DELANCEY/ESSEX',
#  'JOURNAL SQUARE',
#  '161/YANKEE STAD',
#  '23 ST',
#  '59 ST',
#  '86 ST-2 AVE',
#  'FOREST HILLS 71',
#  'CROWN HTS-UTICA',
#  '125 ST',
#  'SUTPHIN-ARCHER',
#  'KEW GARDENS',
#  'WALL ST',
#  "B'WAY-LAFAYETTE",
#  '68ST-HUNTER CO',
#  '33 ST',
#  'THIRTY THIRD ST',
#  '5 AV/53 ST',
#  '66 ST-LINCOLN',
#  'BOWLING GREEN',
#  'JUNCTION BLVD',
#  'GROVE STREET',
#  '3 AV-149 ST',
#  '103 ST-CORONA',
#  '96 ST',
#  'BEDFORD AV',
#  'JAMAICA 179 ST',
#  '168 ST',
#  '34 ST-HUDSON YD',
#  'CORTLANDT ST',
#  '96 ST-2 AVE',
#  'BROOKLYN BRIDGE',
#  'GRAND ST',
#  'LEXINGTON AV/63',
#  '51 ST',
#  '49 ST',
#  'CHURCH AV',
#  'ASTORIA DITMARS',
#  '8 AV',
#  'WHITEHALL S-FRY',
#  'MARCY AV',
#  'PAVONIA/NEWPORT',
#  'CANAL ST',
#  'MYRTLE-WYCKOFF',
#  '30 AV',
#  'WORLD TRADE CTR',
#  'LEXINGTON AV/53',
#  '28 ST',
#  '2 AV',
#  '8 ST-NYU',
#  '90 ST-ELMHURST',
#  'CITY / BUS',
#  'UTICA AV',
#  'SOUTH FERRY',
#  'KINGS HWY',
#  'GRAND-NEWTOWN',
#  '82 ST-JACKSON H',
#  'QUEENSBORO PLZ',
#  'EXCHANGE PLACE',
#  '116 ST-COLUMBIA',
#  '61 ST WOODSIDE',
#  'NEWARK BM BW',
#  'COURT SQ',
#  'BLEECKER ST',
#  'FLATBUSH AV-B.C',
#  'PARKCHESTER',
#  '5 AV/59 ST',
#  '63 DR-REGO PARK',
#  'QUEENS PLAZA',
#  'VERNON-JACKSON',
#  'STEINWAY ST',
#  '137 ST CITY COL',
#  'CONEY IS-STILLW',
#  'ASTOR PL',
#  '77 ST',
#  '1 AV',
#  '57 ST',
#  'YORK ST',
#  'SHEEPSHEAD BAY',
#  'JFK JAMAICA CT1',
#  'HOUSTON ST',
#  '175 ST',
#  'EAST BROADWAY',
#  '149/GRAND CONC',
#  'PRINCE ST',
#  '7 AV',
#  '46 ST BLISS ST',
#  '81 ST-MUSEUM',
#  'WTC-CORTLANDT',
#  'BRIGHTON BEACH',
#  'NOSTRAND AV',
#  'MYRTLE AV',
#  'THIRTY ST',
#  'INWOOD-207 ST',
#  '5 AVE',
#  'CARROLL ST',
#  'ST. GEORGE',
#  'HOYT-SCHER',
#  '21 ST-QNSBRIDGE',
#  'FRANKLIN AV',
#  '33 ST-RAWSON ST',
#  'CANARSIE-ROCKAW',
#  'NEWKIRK PLAZA',
#  '181 ST',
#  'NASSAU AV',
#  'LORIMER ST',
#  '110 ST',
#  'BURNSIDE AV',
#  'LACKAWANNA',
#  'EUCLID AV',
#  '40 ST LOWERY ST',
#  'WOODHAVEN BLVD',
#  'ELMHURST AV',
#  'GREENPOINT AV',
#  'NEVINS ST',
#  'TREMONT AV',
#  'PROSPECT PARK',
#  '157 ST',
#  'HIGH ST',
#  '36 ST',
#  '14TH STREET',
#  'BEDFORD-NOSTRAN',
#  'BROADWAY JCT',
#  '4AV-9 ST',
#  'TWENTY THIRD ST',
#  '53 ST',
#  'NORWOOD 205 ST',
#  '67 AV',
#  'CENTRAL PK N110',
#  'SIMPSON ST',
#  'HARRISON',
#  '46 ST',
#  'HUNTS POINT AV',
#  'MOSHOLU PKWY',
#  '18 ST',
#  '169 ST',
#  'BROADWAY',
#  'BROAD ST',
#  '45 ST',
#  '231 ST',
#  'BAY RIDGE AV',
#  'ROCKAWAY BLVD',
#  'ROOSEVELT ISLND',
#  'DEKALB AV',
#  'GATES AV',
#  'OZONE PK LEFFRT',
#  'GRAHAM AV',
#  'GRAND ARMY PLAZ',
#  'E 180 ST',
#  '145 ST',
#  'UNION ST',
#  '116 ST',
#  '50 ST',
#  'PELHAM BAY PARK',
#  'WOODLAWN',
#  'WEST FARMS SQ',
#  'PARKSIDE AV',
#  'KINGSTON-THROOP',
#  'FORDHAM RD',
#  'SUTTER AV-RUTLD',
#  'CORTELYOU RD',
#  'SPRING ST',
#  '135 ST',
#  'PARSONS BLVD',
#  '3 AV 138 ST',
#  'ELDER AV',
#  'CASTLE HILL AV',
#  '52 ST',
#  '15 ST-PROSPECT',
#  'MORISN AV/SNDVW',
#  '79 ST',
#  'NORTHERN BLVD',
#  'NEWARK C',
#  'WINTHROP ST',
#  'V.CORTLANDT PK',
#  '9TH STREET',
#  'AVENUE J',
#  'FRESH POND RD',
#  'HUNTERS PT AV',
#  'MYRTLE-WILLOUGH',
#  'WESTCHESTER SQ',
#  'NEWKIRK AV',
#  'KOSCIUSZKO ST',
#  '170 ST',
#  '191 ST',
#  'AVENUE M',
#  'BROOK AV',
#  'RALPH AV',
#  '36 AV',
#  'CLARK ST',
#  'FLUSHING AV',
#  'KNICKERBOCKER',
#  '183 ST',
#  'COURT SQ-23 ST',
#  'BAY RIDGE-95 ST',
#  'METS-WILLETS PT',
#  'CITY HALL',
#  'GRANT AV',
#  'CLASSON AV',
#  'JEFFERSON ST',
#  '9 AV',
#  '176 ST',
#  'NEW LOTS AV',
#  '174 ST',
#  '71 ST',
#  'CENTRAL AV',
#  'MORGAN AV',
#  'FRANKLIN ST',
#  'JACKSON AV',
#  'BERGEN ST',
#  'MONTROSE AV',
#  'SARATOGA AV',
#  '69 ST',
#  'ALLERTON AV',
#  '25 AV',
#  'NEWARK HW BMEBE',
#  'KINGSTON AV',
#  'MT EDEN AV',
#  '174-175 STS',
#  'BRIARWOOD',
#  '207 ST',
#  'BOWERY',
#  'NEW UTRECHT AV',
#  'E 149 ST',
#  'SMITH-9 ST',
#  'PENNSYLVANIA AV',
#  'FOREST AVE',
#  'NECK RD',
#  '163 ST-AMSTERDM',
#  'ROCKAWAY AV',
#  'CRESCENT ST',
#  'FREEMAN ST',
#  'BAY PKWY',
#  '80 ST',
#  'JAMAICA VAN WK',
#  'EASTCHSTER/DYRE',
#  'KINGSBRIDGE RD',
#  'MARBLE HILL-225',
#  'RECTOR ST',
#  'SUTPHIN BLVD',
#  'ST LAWRENCE AV',
#  '3 AV',
#  'DITMAS AV',
#  'RIT-MANHATTAN',
#  'HEWES ST',
#  'RIT-ROOSEVELT',
#  '233 ST',
#  'SENECA AVE',
#  'METROPOLITAN AV',
#  'BAYCHESTER AV',
#  'NEW LOTS',
#  'WAKEFIELD/241',
#  'EASTN PKWY-MUSM',
#  'AVENUE H',
#  'LAFAYETTE AV',
#  'BEVERLEY ROAD',
#  '85 ST-FOREST PK',
#  'HARLEM 148 ST',
#  'BUHRE AV',
#  'FAR ROCKAWAY',
#  'CHAUNCEY ST',
#  'PRESIDENT ST',
#  '75 ST-ELDERTS',
#  '20 AV',
#  '138/GRAND CONC',
#  'CLINTON-WASH AV',
#  '4 AV-9 ST',
#  'WILSON AV',
#  'BEVERLY RD',
#  'OCEAN PKWY',
#  '238 ST',
#  '65 ST',
#  '74 ST-BROADWAY',
#  '190 ST',
#  'BURKE AV',
#  'CYPRESS AV',
#  'LONGWOOD AV',
#  '111 ST',
#  'SUTTER AV',
#  'INTERVALE AV',
#  'SHEPHERD AV',
#  'NORWOOD AV',
#  'EAST 105 ST',
#  'CHRISTOPHER ST',
#  'HOWARD BCH JFK',
#  '75 AV',
#  'VAN SICLEN AVE',
#  'CLEVELAND ST',
#  '182-183 STS',
#  '18 AV',
#  'AVENUE N',
#  'HALSEY ST',
#  'NEREID AV',
#  '88 ST',
#  'LIVONIA AV',
#  'LIBERTY AV',
#  'PROSPECT AV',
#  'BAY 50 ST',
#  '39 AV',
#  '219 ST',
#  'AVENUE X',
#  'STERLING ST',
#  'ZEREGA AV',
#  'PELHAM PKWY',
#  'AVENUE U',
#  'BRONX PARK EAST',
#  'PATH WTC 2',
#  'W 8 ST-AQUARIUM',
#  'BEDFORD PK BLVD',
#  'AVENUE P',
#  '6 AV',
#  '225 ST',
#  '167 ST',
#  'JUNIUS ST',
#  'ALABAMA AV',
#  '121 ST',
#  'MORRIS PARK',
#  'BEACH 67 ST',
#  '55 ST',
#  'BEACH 90 ST',
#  'MIDDLETOWN RD',
#  '155 ST',
#  'WHITLOCK AV',
#  '21 ST',
#  'AQUEDUCT RACETR',
#  'BEACH 60 ST',
#  'BUSHWICK AV',
#  'NEPTUNE AV',
#  'BEACH 25 ST',
#  'BOTANIC GARDEN',
#  'CYPRESS HILLS',
#  '215 ST',
#  'ATLANTIC AV',
#  'AVENUE I',
#  'DYCKMAN ST',
#  "E 143/ST MARY'S",
#  'VAN SICLEN AV',
#  'AQUEDUCT N.COND',
#  'BEACH 36 ST',
#  '104 ST',
#  'TOMPKINSVILLE',
#  'ROCKAWAY PARK B',
#  'BEACH 44 ST',
#  'HOYT ST',
#  'BEACH 98 ST',
#  'BROAD CHANNEL',
#  'GUN HILL RD',
#  'BEACH 105 ST',
#  'CATHEDRAL PKWY',
#  'NEWARK HM HE',
#  'PARK PLACE',
#  'ORCHARD BEACH']

# %%
# total number of missing values 
np.count_nonzero(DF_19021.isnull())
# Out:
# 0

# %%
DF_cleaned
# Out:
# C/A             26531
# UNIT            26531
# SCP             26531
# STATION         26531
# LINENAME        26531
# DIVISION        26531
# DATE            26531
# TIME            26531
# DESC            26531
# ENTRIES         26531
# EXITS           26531
# ENTRIES_DIFF    26531
# EXITS_DIFF      26531
# dtype: int64

# %% [markdown]
# ## Info need to extract
# __Find Stations w/ highest Entries and Exits__: But have to exclude locations w/ high tourists (compare between weekend and weekdays)
# __Narrow down which time in day has higher rate__
# __Find demographic info with Gender and industries base on zipcode?__

# %%
# Find Top 5 Max Exits and Entries
DF_19021.ENTRIES.max()
# Out:
# 2129093303

# %%
#groupby station, find the mean for Entries and Exits
DF_19021_Station = DF_19021.groupby('STATION').agg(['mean','count'])
DF_19021_Station
# Out:
#                    ENTRIES        \
#                       mean count
# STATION
# 1 AV             1.415e+08   420
# 103 ST           9.585e+06   630
# 103 ST-CORONA    8.163e+06   378
# 104 ST           5.388e+08   378
# 110 ST           6.482e+06   252
# ...                    ...   ...
# WOODLAWN         6.258e+06   207
# WORLD TRADE CTR  8.880e+07   756
# WTC-CORTLANDT    2.101e+07  1470
# YORK ST          1.459e+07   126
# ZEREGA AV        3.520e+05   246
#
#                 EXITS                                                                 \
#                                                                                 mean
# STATION
# 1 AV                                                     1.466e+08
# 103 ST                                                   7.863e+06
# 103 ST-CORONA                                            8.149e+06
# 104 ST                                                   3.921e+08
# 110 ST                                                   6.195e+06
# ...                                                            ...
# WOODLAWN                                                 2.427e+06
# WORLD TRADE CTR                                          1.023e+08
# WTC-CORTLANDT                                            9.607e+04
# YORK ST                                                  1.168e+07
# ZEREGA AV                                                1.903e+05
#
#
#                 count
# STATION
# 1 AV              420
# 103 ST            630
# 103 ST-CORONA     378
# 104 ST            378
# 110 ST            252
# ...               ...
# WOODLAWN          207
# WORLD TRADE CTR   756
# WTC-CORTLANDT    1470
# YORK ST           126
# ZEREGA AV         246
#
# [378 rows x 4 columns]
